# %% [markdown]
# # Part -1 Python Basics (Variables)

# %% [markdown]
# 1. Print Your Name with your Father name and Date of birth using suitable escape sequence charactor

# %%
# Write your code here
print(f"Name:\"Abdullah\" \nFather Name: \"Abdul Hannan\" \nDate of birth: 03-08-2003")
# Out:
# Name:"Abdullah"
# Father Name: "Abdul Hannan"
# Date of birth: 03-08-2003

# %% [markdown]
# 2. Write your small bio using variables and print it using print function

# %%
# Write your code here
name="Abdullah"
intro= "CSE student"
semester=5
print(f"Hi, I am {name} a {intro} at duet in {semester}th semester")
# Out:
# Hi, I am Abdullah a CSE student at duet in 5th semester

# %% [markdown]
# 3. Write a program in which use all the operators we can use in Python

# %%
# Write your code here
a=5
b=3
print(f"sum of {a} and {b} is {a+b}\nsubtraction of {a} from {b} is {b-a}\nproduct of {a} and {b} is {a*b}\nDivison of {a} and {b} is {a/b}\nReminder of {a} and {b} is {a%b}\n {a} power to {b} is {a**b}\nRounded of division of {a} and {b} is {a//b}")
# Out:
# sum of 5 and 3 is 8
# subtraction of 5 from 3 is -2
# product of 5 and 3 is 15
# Divison of 5 and 3 is 1.6666666666666667
# Reminder of 5 and 3 is 2
#  5 power to 3 is 125
# Rounded of division of 5 and 3 is 1

# %% [markdown]
# 4. Completes the following steps of small task:
#     - Mention Marks of English , Islamiat and Maths out of 100 in 3 different variables
#     - Mention Variable of Total Marks and assign 300 to it
#     - Calculate Percentage

# %%
# Write your code here
eng=98
islamiat=100
math= 99
tot=300
per=((eng+math+islamiat)/tot)*100
print("Percentage:",per,"%")
# Out:
# Percentage: 99 %

# %% [markdown]
# # Part -2 Python Basics (Conditional Statements)

# %% [markdown]
# 1) A company decided to give bonus of 5% to employee if his/her year of service is more than 5 years.
# Ask user for their salary and year of service and print the net bonus amount.

# %%
#Type your code here
salary= int(input("Enter your salary "))
servicesYear=int(input("Enter year of services "))
if servicesYear>5:
  print("Eligible for bonus")
  salary+=salary*0.05
  print(salary, "is your salary")
else:
  print("Not eligible for bonus")
  print(salary, "is your salary")
# Out:
# Enter your salary 4566
# Enter year of services 6
# Eligible for bonus
# 4794.3 is your salary

# %% [markdown]
# 2) Write a program to check whether a person is eligible for voting or not. (accept age from user) if age is greater than 17 eligible otherwise not eligible

# %%
#Type your code here
age= int(input ("Enter your age"))
if age>=17:
  print("Eligible for vote")
else:
  print("Not eligible for vote")
# Out:
# Enter your age19
# Eligible for vote

# %% [markdown]
# 3) Write a program to check whether a number entered by user is even or odd.

# %%
#Type your code here
num=int(input("Enter a number"))
if num%2==0:
  print("Number is even")
elif num%2!=0:
  print("Number is odd")
else:
  print("Write a number")
# Out:
# Enter a number6
# Number is even

# %% [markdown]
# 4) Write a program to check whether a number is divisible by 7 or not.
# Show Answer

# %%
#Type your code here
num=int(input("Enter a number"))
if num%7==0:
  print("Number is divisible by 7 and answer is ", num/7)
elif num%7!=0:
  print("Number is not divible by 7")
else:
  print("Write a number")
# Out:
# Enter a number49
# Number is divisible by 7 and answer is  7.0

# %% [markdown]
# 5) Write a program to display
# "Hello" if a number entered by user is a multiple of five , otherwise print "Bye".

# %%
#Type your code here
num=int(input("Enter a number"))
if num%5==0:
  print("Hello")
else:
  print("Bye")
# Out:
# Enter a number45
# Hello

# %% [markdown]
# 7) Write a program to display the last digit of a number.

# %%
#Type your code here
num=564786
print(num%10)
# Out:
# 6

# %% [markdown]
# 9) Take values of length and breadth of a rectangle from user and print if it is square or rectangle.

# %%
#Type your code here
length= int(input("Enter shape length"))
breadth=int(input("Enter shape breadth"))
if length==breadth:
  print("It is square")
else:
  print("It is rectangle")
# Out:
# Enter shape length5
# Enter shape breadth9
# It is rectangle

# %% [markdown]
# 10) Take two int values from user and print greatest among them.

# %%
# Type your code here
num1= int(input("Enter num1"))
num2=int(input("Enter num2"))
if num1>num2:
  print("Greater number is",num1)
else:
  print("Greater number is",num2)
# Out:
# Enter num14
# Enter num27
# Greater number is 7

# %% [markdown]
# 11) A shop will give discount of 10% if the cost of purchased quantity is more than 1000.
# Ask user for quantity
# Suppose, one unit will cost 100.
# Judge and print total cost for user.

# %%
#Type your code here
qty=int(input("Enter product quantity"))
totCost=qty*100
if totCost>=1000:
  print("Eligible for discount")
  totCost-=totCost*0.1
  print("Your total cost is",totCost)

else:
  print("not Eligible for discount")
  print("Your total cost is", totCost)
# Out:
# Enter product quantity60
# Eligible for discount
# Your total cost is 5400.0

# %% [markdown]
# 12) A school has following rules for grading system:
#
# a. Below 25 - F
#
# b. 25 to 45 - E
#
# c. 45 to 50 - D
#
# d. 50 to 60 - C
#
# e. 60 to 80 - B
#
# f. Above 80 - A
#
# Ask user to enter marks and print the corresponding grade.

# %%
#Type your code here
marks=float(input("enter marks:"))
if marks<25:
  print("Grade:F")
elif marks>=25 and marks<45:
  print("Grade:E")
elif marks>=45 and marks<50:
  print("Grade:D")
elif marks>=50 and marks<60:
  print("Grade:C")
elif marks>=60 and marks<80:
  print("Grade:B")
elif marks>=80 and marks<=100:
  print("Grade:A")
else:
  print("Invalid marks!")

# %% [markdown]
# 14)A student will not be allowed to sit in exam if his/her attendence is less than 75%.
#
# Take following input from user
#
# - Number of classes held
#
# - Number of classes attended.
#
# And print
#
# - percentage of class attended
#
# - Is student is allowed to sit in exam or not.

# %%
#Type your code here
tot_class=int(input("Enter total classes"))
attend_class=int(input("Enter attended classes"))
per_attend=(attend_class/tot_class)*100
print(per_attend)
if per_attend>=75:
  print("Allowed to sit in exam")
else:
  print("Not allowed to sit in exam")
# Out:
# Enter total classes76
# Enter attended classes65
# 85.52631578947368
# Allowed to sit in exam

# %% [markdown]
# 415) Modify the above question to allow student to sit if he/she has medical cause. Ask user if he/she has medical cause or not ( 'Y' or 'N' ) and print accordingly.

# %%
#Type your code here
tot_class=int(input("Enter total classes"))
attend_class=int(input("Enter attended classes"))
med_cause=input("Enter if you have any medical cause(Y for Yes , N for No)")
per_attend=(attend_class/tot_class)*100
print(per_attend)
if per_attend>=75 and med_cause=='Y':
  print("Allowed to sit in exam")
else:
  print("Not allowed to sit in exam")
# Out:
# Enter total classes65
# Enter attended classes64
# Enter if you have any medical cause(Y for Yes , N for No)Y
# 98.46153846153847
# Allowed to sit in exam

# %% [markdown]
# 16) Write a program to check if a year is leap year or not.
#
# If a year is divisible by 4 then it is leap year but if the year is century year like 2000, 1900, 2100 then it must be divisible by 400.

# %%
#Type your code here
year=int(input("Enter year"))
if year%4==0:
  print("Leap year")
elif year%400==0:
  print("Leap year")
else:
  print("Not a leap year")
# Out:
# Enter year2028
# Leap year

# %% [markdown]
# :17) Ask user to enter age, gender ( M or F ),  and then using following rules print their place of service.
#
# if employee is female, then she will work only in urban areas.
#
# if employee is a male and age is in between 20 to 40 then he may work in anywhere
#
# if employee is male and age is in between 40 t0 60 then he will work in urban areas only.
#
# And any other input of age should print "ERROR"

# %%
#Type your code here
age=int(input("Enter your age"))
gender=input("Enter your gender(M or F)")
if gender=='F':
  print("Only in urban areas")
elif gender=='M' and age>=20 and age<=40:
  print("May work anywhere")
elif gender=='M' and age>=40 and age<=60:
  print("Only in urban areas")
else:
  print("ERROR")
# Out:
# Enter your age78
# Enter your gender(M or F)F
# Only in urban areas

# %% [markdown]
# 6. Write a program to calculate the electricity bill (accept number of unit from user) according to the following criteria : Unit Price
# uptp 100 units no charge Next 200 units Rs 5 per unit After 200 units Rs 10 per unit (For example if input unit is 350 than total bill amount is Rs.3500 (For example if input unit is 97 than total bill amount is Rs.0 (For example if input unit is 150 than total bill amount is Rs.750

# %%
#Type your code here
units=int(input("Enter units"))
charges=0
if units<=100:
  print(f"Your bill is Rs.{charges}")
elif units>100 and units<=200:
  charges=units*5
  print(f"Your bill is Rs.{charges}")
elif units>200:
  charges=units*10
  print(f"Your bill is Rs.{charges}")
# Out:
# Enter units150
# Your bill is Rs.750

# %% [markdown]
# 13) Take input of age of 3 people by user and determine oldest and youngest among them.

# %%
#Type your code here
per1=int(input("Enter user-one age"))
per2=int(input("Enter user-two age"))
per3=int(input("Enter user-three age"))
if per1>per2 and per1>per3:
  print("Person 1 is oldest")
  if per2<per3:
    print("Person 2 is youngest")
  else:
    print("Person 3 is youngest")
elif per2>per1 and per2>per3:
  print("Person 2 is oldest")
  if per1<per3:
    print("Person 1 is youngest")
  else:
    print("Person 3 is youngest")
elif per3>per1 and per3>per2:
  print("Person 3 is oldest")
  if per1<per2:
    print("Person 1 is youngest")
  else:
    print("Person 2 is youngest")
else:
  print("All are same age")
# Out:
# Enter your age5
# Enter your age4
# Enter your age6
# Person 3 is oldest
# Person 2 is youngest
