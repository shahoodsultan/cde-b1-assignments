# %% [markdown]
# # Part -1 Python Basics (Variables)

# %% [markdown]
# 1. Print Your Name with your Father name and Date of birth using suitable escape sequence charactor

# %%
print("Name :\'Mohsin Ali\'\nFather Name : \'Muhammad Bashir\'\nDOB : \' 19-January-2005\'")
# Out:
# Name :'Mohsin Ali'
# Father Name : 'Muhammad Bashir'
# DOB : ' 19-January-2005'

# %% [markdown]
# 2. Write your small bio using variables and print it using print function

# %%
name = "Mohsin ALi"
age = 19
University = "SMIU"
department = "BSSE"
print(f"My Name is \'{name}\' \nMy Age is \'{age}\' \nMy university name is \'{University}\' \nMy department is \'{department}\'")
# Out:
# My Name is 'Mohsin ALi'
# My Age is '19'
# My university name is 'SMIU'
# My department is 'BSSE'

# %% [markdown]
# 3. Write a program in which use all the operators we can use in Python

# %%
num1 = 5
num2 = 10
print(num1 + num2)
print(num1 - num2)
print(num1 * num2)
print(num1 / num2)
print(num1 % num2)
# Out:
# 15
# -5
# 50
# 0.5
# 5

# %% [markdown]
# 4. Completes the following steps of small task:
#     - Mention Marks of English , Islamiat and Maths out of 100 in 3 different variables
#     - Mention Variable of Total Marks and assign 300 to it
#     - Calculate Percentage

# %%
engMarks = 80
islMarks = 85
mathMarks = 90
totalMarks = 300
print(f"Percentage is : {((engMarks + islMarks + mathMarks)/totalMarks)*100}")
# Out:
# Percentage is : 85.0

# %% [markdown]
# # Part -2 Python Basics (Conditional Statements)

# %% [markdown]
# 1) A company decided to give bonus of 5% to employee if his/her year of service is more than 5 years.
# Ask user for their salary and year of service and print the net bonus amount.

# %%
no_service = int(input("Enter your No. of experience : "))
if (no_service > 5):
    salary = float(input("Enter Your Salary : "))
    print(f"Bonus : {salary * 0.05}")
else:
    print("Not Eligible")
# Out:
# Bonus : 2500.0

# %% [markdown]
# 2) Write a program to check whether a person is eligible for voting or not. (accept age from user) if age is greater than 17 eligible otherwise not eligible

# %%
age = int(input("Enter your age : "))
if (age > 17) : 
    print("Yes, You're eligble for Voting")
else:
    print("No, You're not eligible")
# Out:
# Yes, You're eligble for Voting

# %% [markdown]
# 3) Write a program to check whether a number entered by user is even or odd.

# %%
num = int(input("Enter a number : "))
if (num % 2 == 0) : 
    print(f"{num} is an Even Number")
else:
    print(f"{num} is an Odd number")
# Out:
# 13 is Odd number

# %% [markdown]
# 4) Write a program to check whether a number is divisible by 7 or not.
# Show Answer

# %%
num = int(input("Enter a number : "))
if (num % 7 == 0) : 
    print(f"Yes, {num} is Divisble by 7")
else:
    print(f"No, {num} is not Divisible by 7")
# Out:
# No, 65 is not Divisible by 7

# %% [markdown]
# 5) Write a program to display
# "Hello" if a number entered by user is a multiple of five , otherwise print "Bye".

# %%
num = int(input("Enter number : "))
if(num != 0 and num % 5 == 0):
    print("Hello")
else:
    print("Bye")
# Out:
# Hello

# %% [markdown]
# 7) Write a program to display the last digit of a number.

# %%
number = int(input("Enter a number: "))
last_digit = number % 10
print(f"The last digit of {number} is {last_digit}.")
# Out:
# The last digit of 22226 is 6.

# %% [markdown]
# 9) Take values of length and breadth of a rectangle from user and print if it is square or rectangle.

# %%
length = int(input("Enter length : "))
width = int(input("Enter width : "))

if(length == width):
    print("It is a Square")
else:
    print("It is a Rectangle")
# Out:
# It is a Square

# %% [markdown]
# 10) Take two int values from user and print greatest among them.

# %%
num1 = int(input("Enter Num1 : "))
num2 = int(input("Enter Num2 : "))

if(num1 > num2):
    print(f"{num1}")
else:
    print(f"{num2}")
# Out:
# 100

# %% [markdown]
# 11) A shop will give discount of 10% if the cost of purchased quantity is more than 1000.
# Ask user for quantity
# Suppose, one unit will cost 100.
# Judge and print total cost for user.

# %%
quantity = int(input("Enter the quantity of items: "))
cost_per_unit = 100
total_cost = quantity * cost_per_unit

if (total_cost > 1000):
    discount = total_cost * 0.10
    total_cost -= discount 

print(f"The total cost after any applicable discount is: {total_cost}")
# Out:
# The total cost after any applicable discount is: 1800.0

# %% [markdown]
# 12) A school has following rules for grading system:
#
# a. Below 25 - F
#
# b. 25 to 45 - E
#
# c. 45 to 50 - D
#
# d. 50 to 60 - C
#
# e. 60 to 80 - B
#
# f. Above 80 - A
#
# Ask user to enter marks and print the corresponding grade.

# %%
per=float(input("Enter Your Percantage : "))
if(per > 80 and per <= 100):
    print("Grade : A")
elif (per >= 60 and per <= 80):
    print("Grade : B")
elif (per >= 50 and per < 60):
    print("Grade : C")
elif (per >= 40 and per< 50):
    print("Grade : D")
elif(per >= 25 and per < 40):
    print("Grade : E")
elif (per >= 0 and per < 25) :
    print("Grade : F")
else:
    print("Invalid Input !")

# %% [markdown]
# 14)A student will not be allowed to sit in exam if his/her attendence is less than 75%.
#
# Take following input from user
#
# - Number of classes held
#
# - Number of classes attended.
#
# And print
#
# - percentage of class attended
#
# - Is student is allowed to sit in exam or not.

# %%
classHeld = 16
classAttend = int(input("Enter the classes Attended : "))

percentClass = (classAttend / classHeld) * 100

if(percentClass >= 75):
    print(percentClass)
    print("Student is allowed to sit in exam")
else:
    print(percentClass)
    print("Student is not allowed to sit in exam")
# Out:
# 62.5
# Student is not allowed to sit in exam

# %% [markdown]
# 15) Modify the above question to allow student to sit if he/she has medical cause. Ask user if he/she has medical cause or not ( 'Y' or 'N' ) and print accordingly.

# %%
classHeld = 16
classAttend = int(input("Enter the classes Attended : "))
medCause = input("If Med Cause Y otherwise N")
percentClass = (classAttend / classHeld) * 100

if(percentClass >= 75):
    print(percentClass)
    print("Student is allowed to sit in exam")
elif(percentClass >= 75 or medCause == "Y"):
    print(percentClass)
    print("Student is allowed to sit in exam")
else:
    print(percentClass)
    print("Student is not allowed to sit in exam")
# Out:
# 93.75
# Student is allowed to sit in exam

# %% [markdown]
# 16) Write a program to check if a year is leap year or not.
#
# If a year is divisible by 4 then it is leap year but if the year is century year like 2000, 1900, 2100 then it must be divisible by 400.

# %%
year = int(input("Enter a year: "))

if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print(f"{year} is a leap year.")
else:
    print(f"{year} is not a leap year.")

# %% [markdown]
# 17) Ask user to enter age, gender ( M or F ), marital status ( Y or N ) and then using following rules print their place of service.
#
# if employee is female, then she will work only in urban areas.
#
# if employee is a male and age is in between 20 to 40 then he may work in anywhere
#
# if employee is male and age is in between 40 t0 60 then he will work in urban areas only.
#
# And any other input of age should print "ERROR"

# %%
gender = input("Enter your Gender M or F : ")
if (gender == "F"):
    print("Work only in Urban Area Only")
elif (gender == "M"):
    age = int(input("Enter Your Age : "))
    if(age > 20 and age < 40):
        print("Work in any area")
    elif( age >= 40 and age < 60):
        print("Work in Urban Area Only")
    else:
        print("Error")
else:
    print("Invalid Gender")

# %% [markdown]
# 6) Write a program to calculate the electricity bill (accept number of unit from user) according to the following criteria :
#      Unit                                                     Price
# uptp 100 units                                             no charge
# Next 200 units                                              Rs 5 per unit
# After 200 units                                             Rs 10 per unit
# (For example if input unit is 350 than total bill amount is Rs.3500
# (For example if input unit is 97 than total bill amount is Rs.0
# (For example if input unit is 150 than total bill amount is Rs.750

# %% [markdown]
# 13) Take input of age of 3 people by user and determine oldest and youngest among them.

# %%
age1 = int(input("Enter the age of the first person: "))
age2 = int(input("Enter the age of the second person: "))
age3 = int(input("Enter the age of the third person: "))

if (age1 > age2 and age1 > age3):
    oldest = age1
elif (age2 > age1 and age2 > age3):
    oldest = age2
else:
    oldest = age3

if (age1 < age2 and age1 < age3):
    youngest = age1
elif (age2 < age1 and age2 < age3):
    youngest = age2
else:
    youngest = age3

print(f"The oldest person is {oldest} years old.")
print(f"The youngest person is {youngest} years old.")
# Out:
# The oldest person is 22 years old.
# The youngest person is 20 years old.
