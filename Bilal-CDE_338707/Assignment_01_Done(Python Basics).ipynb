# %% [markdown]
# # Part -1 Python Basics (Variables)

# %% [markdown]
# 1. Print Your Name with your Father name and Date of birth using suitable escape sequence charactor

# %%
#name = "Muhammad Bilal"
#f_name = "Muhammad Iqbal"
#dob = "12-January-1993"

print("Muhammad Bilal" + " " + "Muhammad Iqbal" + " " + "12-January-1993")                # one way
#print(f"My name is {name}, my father name is {f_name} and my date of birht is {dob}.")      # another way
# Out:
# Muhammad Bilal Muhammad Iqbal 12-January-1993

# %% [markdown]
# 2. Write your small bio using variables and print it using print function

# %%
name = "Muhammad Bilal"
age = "30"
job_status = "Currently I am working as a data analyst at Pak Qatar Takaful"

print(f"My name is {name}, I am {age} years old and {job_status}. ")
# Out:
# My name is Muhammad Bilal, I am 30 years old and Currently I am working as a data analyst at Pak Qatar Takaful.

# %% [markdown]
# 3. Write a program in which use all the operators we can use in Python

# %%
a = (2+8) - (5/20) + ((17-14+7) * 3) + 5 + (5 // 5)
print(a)
print(a == 45.75)
print(a != 45.75)
a += 2
print(a)
a -= 7
print(a)
# Out:
# 45.75
# True
# False
# 47.75
# 40.75

# %% [markdown]
# 4. Completes the following steps of small task:
#     - Mention Marks of English , Islamiat and Maths out of 100 in 3 different variables
#     - Mention Variable of Total Marks and assign 300 to it
#     - Calculate Percentage

# %%
english = 71
islamiat = 79
maths = 82
total = 300

marks_obtained = english + islamiat + maths
percentage = (marks_obtained / total) * 100

print(percentage)
# Out:
# 77.33333333333333

# %% [markdown]
# # Part -2 Python Basics (Conditional Statements)

# %% [markdown]
# 1) A company decided to give bonus of 5% to employee if his/her year of service is more than 5 years.
# Ask user for their salary and year of service and print the net bonus amount.

# %%
service = float(input("Enter your year of service: "))
salary = int(input("Enter your salary: "))

if service > 5:
  bonus = int(salary * 0.05)
  print(f"\nYour bonus amount is: {bonus}\n\nNote: Its just a bonus amount not an increment")
else:
  print("you are not eligible for bonus")
# Out:
# Enter your year of service: 7
# Enter your salary: 120000
#
# Your bonus amount is: 6000
#
# Note: Its just a bonus amount not an increment

# %% [markdown]
# 5
# 2) Write a program to check whether a person is eligible for voting or not. (accept age from user) if age is greater than 17 eligible otherwise not eligible

# %%
age = int(input("Enter your age: "))

if age > 17:
  print("You are aligible for vote")
else:
  print("You are not eligible for vote")
# Out:
# Enter your age: 18
# You are aligible for vote

# %% [markdown]
# 3) Write a program to check whether a number entered by user is even or odd.

# %%
number = int(input("Entre any number: "))

if number % 2 == 0:
  print("The number user entered is Even")
else:
  print("The number user entered is Odd")
# Out:
# Entre any number: 18
# The number user entered is Even

# %% [markdown]
# 4) Write a program to check whether a number is divisible by 7 or not.
# Show Answer

# %%
user_number = int(input("Enter any number: "))
number = 7

if user_number % number == 0:
  print(f"{user_number} is divisible by {number}")
else:
  print(f"{user_number} is not divisible by {number}")
# Out:
# Enter any number: 6702045
# 6702045 is divisible by 7

# %% [markdown]
# 5) Write a program to display
# "Hello" if a number entered by user is a multiple of five , otherwise print "Bye".

# %%
user_number = int(input("Enter any number: "))
number = 5

if user_number % number == 0:
  print("Hello")
else:
  print("Bye")
# Out:
# Enter any number: 750
# Hello

# %% [markdown]
# 7) Write a program to display the last digit of a number.

# %%
number = input("Enter any number: ")

print(number[-1])
# Out:
# Enter any number: 75894
# 4

# %% [markdown]
# 9) Take values of length and breadth of a rectangle from user and print if it is square or rectangle.

# %%
length = float(input("Enter lenght: "))
breadth = float(input("Enter breadth: "))

if length == breadth:
  print("Its Square")
else:
  print("Its Rectengular")
# Out:
# Enter lenght: 22
# Enter breadth: 21
# Its Rectengular

# %% [markdown]
# 10) Take two int values from user and print greatest among them.

# %%
num1 = int(input("Enter any number: "))
num2 = int(input("Enter any number: "))

if num1 > num2:
  print(num1)
else:
  print(num2)
# Out:
# Enter any number: 23
# Enter any number: 17
# 23

# %% [markdown]
# 11) A shop will give discount of 10% if the cost of purchased quantity is more than 1000.
# Ask user for quantity
# Suppose, one unit will cost 100.
# Judge and print total cost for user.

# %%
purchased_quantity = int(input("Enter a quantity you purchased: "))
unit_price = 100
total_cost = int(purchased_quantity * unit_price)
after_discount = int(total_cost - (total_cost * 0.10))
if purchased_quantity > 1000:
  #after_discount = (purchased_quantity * 0.10) - purchased_quantity
  print(f"Congrats! you are eligible for discount, your total cost is {after_discount}")
else:
  print(f"Your total cost is {total_cost}")
# Out:
# Enter a quantity you purchased: 1050
# Congrats! you are eligible for discount, your total cost is 94500

# %% [markdown]
# 12) A school has following rules for grading system:
#
# a. Below 25 - F
#
# b. 25 to 45 - E
#
# c. 45 to 50 - D
#
# d. 50 to 60 - C
#
# e. 60 to 80 - B
#
# f. Above 80 - A
#
# Ask user to enter marks and print the corresponding grade.

# %%
marks = int(input("Enter your marks: "))

if marks < 25:
  print("You are fail")
elif marks <= 45:
  print("You are pass with E grade")
elif marks <= 50:
  print("You are pass with D grade")
elif marks <= 60:
  print("You are pass with C grade")
elif marks <= 80:
  print("You are pass with B grade")
elif marks <= 100:
  print("You are pass with A grade")
else:
  print("Please enter correct Marks")
# Out:
# Enter your marks: 83
# You are pass with A grade

# %% [markdown]
# 14)A student will not be allowed to sit in exam if his/her attendence is less than 75%.
#
# Take following input from user
#
# - Number of classes held
#
# - Number of classes attended.
#
# And print
#
# - percentage of class attended
#
# - Is student is allowed to sit in exam or not.

# %%
num_of_classes = int(input("Enter total number of classes held: "))
classes_attended = int(input("Enter number of classes you attended: "))

perc_of_attendance = classes_attended / num_of_classes * 100

print(f"Percentage of class attendance is {perc_of_attendance}%")

if perc_of_attendance < 75:
  print("Student is not allowed to sit in Exam")
else:
  print("Student is allowed to sit in Exam")
# Out:
# Enter total number of classes held: 30
# Enter number of classes you attended: 28
# Percentage of class attendance is 93.33333333333333%
# Student is allowed to sit in Exam

# %% [markdown]
# 15) Modify the above question to allow student to sit if he/she has medical cause. Ask user if he/she has medical cause or not ( 'Y' or 'N' ) and print accordingly.

# %%
num_of_classes = int(input("Enter total number of classes held: "))
classes_attended = int(input("Enter number of classes you attended: "))


perc_of_attendance = classes_attended / num_of_classes * 100

print(f"Percentage of class attendance is {perc_of_attendance}%")

if perc_of_attendance >= 75:
  print("Student is allowed to sit in Exam")
else:
  medical_issue = str(input("Enter 'Y' or 'N':" )).strip().upper()
  if medical_issue == "Y":
    print("You are allowed to sit in exam")
  else:
    print("You are not allowed to sit in exam")
# Out:
# Enter total number of classes held: 28
# Enter number of classes you attended: 20
# Percentage of class attendance is 71.42857142857143%
# Enter 'Y' or 'N':n
# You are not allowed to sit in exam

# %% [markdown]
# 16) Write a program to check if a year is leap year or not.
#
# If a year is divisible by 4 then it is leap year but if the year is century year like 2000, 1900, 2100 then it must be divisible by 400.

# %%
year = int(input("Enter any Year: "))

if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
  print(f"{year} is a leap year")
else:
  print(f"{year} is not a leap year")
# Out:
# Enter any Year: 2025
# 2025 is not a leap year

# %% [markdown]
# 17) Ask user to enter age, gender ( M or F ), marital status ( Y or N ) and then using following rules print their place of service.
#
# if employee is female, then she will work only in urban areas.
#
# if employee is a male and age is in between 20 to 40 then he may work in anywhere
#
# if employee is male and age is in between 40 t0 60 then he will work in urban areas only.
#
# And any other input of age should print "ERROR"

# %%
age = int(input("Enter your age: "))
gender = str(input("Enter your gender 'M' or 'F': ")).strip().upper()
marital_status = str(input("Enter your marital status 'Y' or 'N': ")).strip().upper()

if gender == "F":
  print("You are work in Urban areas")
else:
  if 20 <= age <= 40:
    print("You are allow to work anywhere")
  elif 40 <= age <= 60:
    print("You are eligible to work only in urban areas")
  else:
    print("ERROR")
# Out:
# Enter your age: 43
# Enter your gender 'M' or 'F': m
# Enter your marital status 'Y' or 'N': y
# You are eligible to work only in urban areas

# %% [markdown]
# 6) Write a program to calculate the electricity bill (accept number of unit from user) according to the following criteria :
#      Unit                                                     Price
# uptp 100 units                                             no charge
# Next 200 units                                              Rs 5 per unit
# After 200 units                                             Rs 10 per unit
# (For example if input unit is 350 than total bill amount is Rs.3500
# (For example if input unit is 97 than total bill amount is Rs.0
# (For example if input unit is 150 than total bill amount is Rs.750

# %%
number_of_unit = int(input("Enter number of units: "))

if number_of_unit < 100:
  print("your total bill amount is Rs.0")
else:
  if 100 <= number_of_unit <= 200:
    total_bill = number_of_unit * 5
    print(f"Your total bill amount is Rs.{total_bill}")
  else:
    total_bill = number_of_unit * 10
    print(f"Your total bill amount is Rs.{total_bill}")
# Out:
# Enter number of units: 350
# Your total bill amount is Rs.3500

# %% [markdown]
# 13) Take input of age of 3 people by user and determine oldest and youngest among them.

# %%
age1 = int(input("Enter your age: "))
age2 = int(input("Enter your age: "))
age3 = int(input("Enter your age: "))

if age1 > age2 and age1 > age3:
  oldest = age1
elif age2 > age1 and age2 > age3:
  oldest = age2
else:
  oldest = age3

if age1 < age2 and age1 < age3:
  youngest = age1
elif age2 < age1 and age2 < age3:
  youngest = age2
else:
  youngest = age3

print(f"The oldest one is {oldest}")
print(f"The youngest one is {youngest}")
# Out:
# Enter your age: 17
# Enter your age: 25
# Enter your age: 23
# The oldest one is 25
# The youngest one is 17
